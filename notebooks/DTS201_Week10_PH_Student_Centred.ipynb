# %% [markdown]
# <a href="https://colab.research.google.com/github/omosanyasalama-blip/OOU_DTS201_Introduction_to_Data_Science/blob/main/notebooks/DTS201_Week10_PH_Student_Centred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DTS 201 – INTRODUCTION TO DATA SCIENCE
# ## WEEK 10 PRACTICAL (PH): PYTHON PROGRAMMING FOR DATA SCIENCE – BASICS
#
# **Instructor:** DR SAKINAT FOLORRUNSO – ASSOCIATE PROFESSOR OF AI SYSTEMS AND FAIR DATA
# **Department:** COMPUTER SCIENCES, OLABISI ONABANJO UNIVERSITY, AGO-IWOYE, OGUN STATE, NIGERIA
#
# ---
#
# ### 🎯 Practical Learning Objectives (Week 10)
#
# By the end of this practical session, you should be able to:
#
# - Write and run basic **Python code** in a Jupyter Notebook or Google Colab.
# - Use **variables**, **data types**, **lists**, **dictionaries**, and **loops**.
# - Define and call simple **functions**.
# - Perform basic **data operations** using `pandas` (loading, selecting, filtering).
# - Understand how these programming skills support later topics in **data science and AI**.
#
# > 💡 This week replaces the “Basics of R programming” in the outline with **Python for Data Science**, aligning with tools you are already using in earlier weeks.

# %% [markdown]
# ## 1. Running Python Code in a Notebook
#
# You have already seen Jupyter/Colab in previous weeks.
# Here we focus on writing small Python **code snippets** to build core programming skills.
#
# Two main cell types:
#
# - **Code cells** – where you write Python code and run it.
# - **Markdown cells** – where you write explanations, titles, and notes.
#
# > ✏️ **Student Task 1:**
# > - Insert a **new code cell** below this one in your environment.
# > - Type `print("Hello DTS 201!")` in the new cell and run it.
# > - Confirm that the output appears directly under the cell.

# %% [markdown]
# ANSWER

# %%
print("Hello DTS 201!")
# Out:
# Hello DTS 201!

# %% [markdown]
# ## 2. Variables and Basic Data Types in Python

# %% [markdown]
# Python supports several basic data types that are very useful in data science:
#
# - **int** – integers (e.g. 1, 20, -5)
# - **float** – decimal numbers (e.g. 3.14, 0.5, -2.0)
# - **str** – strings (text) (e.g. `"OOU"`, `"Data Science"`)
# - **bool** – boolean values (`True` or `False`)
#
# We assign values to **variables** using the `=` sign.

# %%
# Create an integer variable representing a student's age
age = 20  # 'age' stores the whole number 20

# Create a float variable representing a student's exam score
score = 72.5  # 'score' stores a decimal number (float)

# Create a string variable representing a student's name
name = "Amina"  # 'name' stores a sequence of characters (text)

# Create a boolean variable representing whether the student passed
passed = True  # 'passed' is True if the student passed, False otherwise

# Print the variables and their types
print("Age:", age, "| Type:", type(age))
print("Score:", score, "| Type:", type(score))
print("Name:", name, "| Type:", type(name))
print("Passed:", passed, "| Type:", type(passed))
# Out:
# Age: 20 | Type: <class 'int'>
# Score: 72.5 | Type: <class 'float'>
# Name: Amina | Type: <class 'str'>
# Passed: True | Type: <class 'bool'>

# %% [markdown]
# > ✏️ **Student Task 2:**
# > - Create your own variables for:
# >   - `course_code` (e.g. `"DTS 201"`)
# >   - `units` (e.g. `3`)
# >   - `registered` (True/False)
# > - Print them out with their types using `type(...)`.

# %% [markdown]
# ANSWER

# %%
# Create an integer variable representing a student's coures unit
unit = 3  # 'unit' stores the whole number 3

# Create a string variable representing a student's course_code
course_code = "DTS 201"  # 'course_code' stores a sequence of characters (text)

# Create a boolean variable representing whether the student registered
registered = True  # 'registered' is True if the student registered, False

# Print the variables and their types
print("Course_code:", course_code, "| Type:", type(course_code))
print("Unit:", unit, "| Type:", type(unit))
print("Registered:", registered, "| Type:", type(registered))
# Out:
# Course_code: DTS 201 | Type: <class 'str'>
# Unit: 3 | Type: <class 'int'>
# Registered: True | Type: <class 'bool'>

# %% [markdown]
# ## 3. Basic Arithmetic and Comparisons

# %% [markdown]
# Python can be used as a simple calculator for arithmetic operations and for comparing values.
#
# Common arithmetic operators:
#
# - `+` (addition), `-` (subtraction), `*` (multiplication), `/` (division), `//` (integer division), `%` (modulo), `**` (power).
#
# Comparison operators (return `True` or `False`):
#
# - `==`, `!=`, `>`, `<`, `>=`, `<=`.

# %%
# Example: basic arithmetic with numbers
a = 10        # First number
b = 3         # Second number

sum_ab = a + b        # Addition
diff_ab = a - b       # Subtraction
prod_ab = a * b       # Multiplication
quot_ab = a / b       # Division (float result)
int_div = a // b      # Integer division (no remainder)
mod_ab = a % b        # Remainder after division
power_ab = a ** b     # a raised to the power b

print("a + b =", sum_ab)
print("a - b =", diff_ab)
print("a * b =", prod_ab)
print("a / b =", quot_ab)
print("a // b =", int_div)
print("a % b =", mod_ab)
print("a ** b =", power_ab)
# Out:
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a // b = 3
# a % b = 1
# a ** b = 1000

# %%
# Example: comparison operators
x = 75       # A sample exam score
y = 50       # Pass mark

print("x > y:", x > y)      # Is x greater than y?
print("x == y:", x == y)    # Is x equal to y?
print("x >= y:", x >= y)    # Is x greater than or equal to y?
print("x < y:", x < y)      # Is x less than y?
# Out:
# x > y: True
# x == y: False
# x >= y: True
# x < y: False

# %% [markdown]
# > ✏️ **Student Task 3:**
# > - Write an expression to check whether a student with `score = 45` has passed (pass mark = 50).
# > - Store the result in a variable called `has_passed` and print it.

# %% [markdown]
# ANSWER

# %%
score = 45  # Student's score
pass_mark = 50 # Pass mark

has_passed = score >= pass_mark  # Check if score is greater than or equal to the pass mark

print("Student has passed:", has_passed)
# Out:
# Student has passed: False

# %% [markdown]
# ## 4. Working with Lists

# %% [markdown]
# A **list** is an ordered collection of items. Lists can store numbers, strings, or even mixtures of types.
#
# Lists are defined using **square brackets**: `[ ... ]`.

# %%
# Create a list of exam scores
scores = [72, 65, 88, 90, 54]  # A list containing five integers

# Print the entire list
print("Scores list:", scores)

# Access individual elements by index (starting at 0)
print("First score:", scores[0])   # Element at index 0
print("Third score:", scores[2])   # Element at index 2

# Add a new score to the end of the list
scores.append(79)  # Append 79 to the list

# Print updated list
print("Updated scores list:", scores)

# Compute simple statistics using built-in functions
print("Number of scores:", len(scores))   # len() gives the list length
print("Maximum score:", max(scores))      # max() gives the largest value
print("Minimum score:", min(scores))      # min() gives the smallest value
print("Average score:", sum(scores) / len(scores))  # Average = sum / count
# Out:
# Scores list: [72, 65, 88, 90, 54]
# First score: 72
# Third score: 88
# Updated scores list: [72, 65, 88, 90, 54, 79]
# Number of scores: 6
# Maximum score: 90
# Minimum score: 54
# Average score: 74.66666666666667

# %% [markdown]
# > ✏️ **Student Task 4:**
# > - Create a list called `ages` with at least 5 different ages.
# > - Print the youngest and oldest age.
# > - Compute the average age.

# %% [markdown]
#  ANSWER

# %%
# Create a list of ages
ages = [23, 19, 30, 20, 17, 21, 26] # At least 5 different ages

# Print the youngest age
youngest_age = min(ages)
print("Youngest age:", youngest_age)

# Print the oldest age
oldest_age = max(ages)
print("Oldest age:", oldest_age)

# Compute the average age
average_age = sum(ages) / len(ages)
print("Average age:", average_age)
# Out:
# Youngest age: 17
# Oldest age: 30
# Average age: 22.285714285714285

# %% [markdown]
# ## 5. Dictionaries (Key–Value Pairs)

# %% [markdown]
# A **dictionary** stores data as **key–value pairs**.
#
# Example:
#
# ```python
# student = {
#     "name": "Amina",
#     "age": 20,
#     "department": "Computer Science"
# }
# ```
#
# You access values using keys like `student["name"]`.

# %%
# Create a dictionary to store a student's information
student = {
    "name": "Amina",                # Key 'name' maps to the string "Amina"
    "age": 20,                      # Key 'age' maps to the integer 20
    "department": "Computer Science",  # Key 'department' maps to a string
    "passed": True                  # Key 'passed' maps to a boolean
}

# Access values by their keys
print("Student name:", student["name"])
print("Student age:", student["age"])
print("Department:", student["department"])
print("Passed?:", student["passed"])

# Add a new key–value pair for 'level'
student["level"] = 200  # Add a new entry with key 'level' and value 200

print("Updated student dictionary:", student)
# Out:
# Student name: Amina
# Student age: 20
# Department: Computer Science
# Passed?: True
# Updated student dictionary: {'name': 'Amina', 'age': 20, 'department': 'Computer Science', 'passed': True, 'level': 200}

# %% [markdown]
# > ✏️ **Student Task 5:**
# > - Create your own dictionary called `course` with keys like `"code"`, `"title"`, `"units"`, and `"semester"`.
# > - Print out a sentence using values from the dictionary, e.g. `"DTS 201 is a 3-unit course."`

# %% [markdown]
# ANSWER

# %%
# Create a dictionary called 'course'
course = {
    "code": "SEN 201",
    "title": "INTRODUCTION TO SOFTWARE ENGINEERING",
    "units": 2,
    "semester": "Harmattan Semester"
}

# Print a sentence using values from the dictionary
print(f"{course['code']} is a {course['units']}-unit course, titled '{course['title']}'.")
# Out:
# SEN 201 is a 2-unit course, titled 'INTRODUCTION TO SOFTWARE ENGINEERING'.

# %% [markdown]
# ## 6. Decision-Making with `if`, `elif`, and `else`

# %% [markdown]
# We use **if-statements** to run certain blocks of code only when a condition is `True`.

# %%
# Example: grade classification based on score
score = 63  # You can change this value to test different branches

# Use if/elif/else to assign a grade based on score
if score >= 70:
    grade = "A"       # If score is 70 or higher, grade is A
elif score >= 60:
    grade = "B"       # If score is between 60 and 69, grade is B
elif score >= 50:
    grade = "C"       # If score is between 50 and 44, grade is C
elif score >= 45:
    grade = "D"       # If score is between 45 and 49, grade is D
else:
    grade = "F"       # Any score below 49 gets an F

print("Score:", score)
print("Grade:", grade)
# Out:
# Score: 63
# Grade: B

# %% [markdown]
# > ✏️ **Student Task 6:**
# > - Change `score` to different values and note how the grade changes.
# > - Modify the grading scale to include `"D"` between 45 and 49 if you wish.

# %% [markdown]
# ## 7. Loops: Repeating Actions with `for`

# %% [markdown]
# Loops allow us to repeat operations over lists or ranges without writing the same line many times.

# %%
# Example: print each score in a list and check if it is a pass or fail
scores = [72, 65, 88, 90, 54]  # List of exam scores
pass_mark = 50                 # Pass mark threshold

# Loop over each score in the list
for s in scores:
    # For each score, check if it meets the pass mark
    if s >= pass_mark:
        status = "PASS"  # Status is PASS if score >= pass_mark
    else:
        status = "FAIL"  # Status is FAIL otherwise

    # Print out the score and its status
    print(f"Score: {s} → {status}")
# Out:
# Score: 72 → PASS
# Score: 65 → PASS
# Score: 88 → PASS
# Score: 90 → PASS
# Score: 54 → PASS

# %% [markdown]
# > ✏️ **Student Task 7:**
# > - Create a list of 5 student names.
# > - Use a `for` loop to print a welcome message for each student, e.g. `"Welcome, Amina!"`.

# %% [markdown]
# ANSWER

# %%
# Create a list of 5 student names
student_names = ["Deji", "Tola", "Vivian", "Ryan", "Ade"]

# Use a for loop to print a welcome message for each student
for name in student_names:
    print(f"Welcome, {name}!")
# Out:
# Welcome, Deji!
# Welcome, Tola!
# Welcome, Vivian!
# Welcome, Ryan!
# Welcome, Ade!

# %% [markdown]
# ## 8. Writing Your Own Functions

# %% [markdown]
# A **function** is a reusable block of code that performs a specific task.
#
# We define functions using the `def` keyword.

# %%
# Define a function to compute the average of a list of numbers
def compute_average(values):
    """Return the average (mean) of a list of numerical values."""
    total = sum(values)         # Compute the sum of all values in the list
    count = len(values)         # Count how many values are in the list
    average = total / count     # Divide sum by count to get the mean
    return average              # Return the computed average

# Use the function on a list of scores
scores = [72, 65, 88, 90, 54]

avg_score = compute_average(scores)  # Call the function and store the result

print("Scores:", scores)
print("Average score:", avg_score)
# Out:
# Scores: [72, 65, 88, 90, 54]
# Average score: 73.8

# %% [markdown]
# > ✏️ **Student Task 8:**
# > - Write a function called `classify_score(score)` that returns `"PASS"` if score ≥ 50 and `"FAIL"` otherwise.
# > - Test your function on several score values.

# %% [markdown]
# ANSWER

# %%
# Define the classify_score function
def classify_score(score):
    """Returns 'PASS' if score is 50 or greater, 'FAIL' otherwise."""
    if score >= 50:
        return "PASS"
    else:
        return "FAIL"

# Test the function with several score values
print(f"Score 83: {classify_score(83)}")
print(f"Score 42: {classify_score(42)}")
print(f"Score 55: {classify_score(55)}")
print(f"Score 76: {classify_score(76)}")
print(f"Score 29: {classify_score(29)}")
# Out:
# Score 83: PASS
# Score 42: FAIL
# Score 55: PASS
# Score 76: PASS
# Score 29: FAIL

# %% [markdown]
# ## 9. Basic Data Operations with `pandas`

# %% [markdown]
# `pandas` is a core library for data science in Python.
# It provides the **DataFrame**, which is like an improved, programmable spreadsheet.
#
# Here we will create a small DataFrame and perform basic operations.

# %%
# Import pandas (if not already imported above)
import pandas as pd  # Alias 'pd' is a common convention

# Create a simple DataFrame from a dictionary
data = {
    "Name": ["Amina", "Bola", "Chidi", "Damilola"],  # List of student names
    "Score": [72, 65, 88, 54],                      # Corresponding scores
    "Department": ["CS", "CS", "IT", "CS"]          # Departments
}

students_df = pd.DataFrame(data)  # Convert the dictionary into a DataFrame

# Display the entire DataFrame
students_df
# Out:
#        Name  Score Department
# 0     Amina     72         CS
# 1      Bola     65         CS
# 2     Chidi     88         IT
# 3  Damilola     54         CS

# %%
# View basic information about the DataFrame
print("Shape (rows, columns):", students_df.shape)  # Number of rows and columns
print("\nInfo:")
print(students_df.info())  # Data types and non-null counts
# Out:
# Shape (rows, columns): (4, 3)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        4 non-null      object
#  1   Score       4 non-null      int64
#  2   Department  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
# None

# %%
# Select a single column
scores_series = students_df["Score"]  # Series of scores
print("Scores column:")
print(scores_series)

# Compute average score using pandas
print("\nAverage score (pandas):", students_df["Score"].mean())
# Out:
# Scores column:
# 0    72
# 1    65
# 2    88
# 3    54
# Name: Score, dtype: int64
#
# Average score (pandas): 69.75

# %%
# Filter rows where Score is >= 70
passed_df = students_df[students_df["Score"] >= 70]  # Select only rows with Score >= 70

print("Students who scored 70 and above:")
print(passed_df)
# Out:
# Students who scored 70 and above:
#     Name  Score Department
# 0  Amina     72         CS
# 2  Chidi     88         IT

# %% [markdown]
# > ✏️ **Student Task 9:**
# > - Add a new column called `"Status"` to `students_df` that contains `"PASS"` if Score ≥ 50 and `"FAIL"` otherwise.
# > - Count how many students passed and how many failed using `value_counts()`.

# %% [markdown]
# ## 10. Mini Programming Exercise

# %% [markdown]
# > 🧪 **Student Activity:**
# > Using what you have learned in this practical:
#
# 1. Create a small dataset (either as a list of dictionaries or using a dictionary-of-lists) representing at least **5 students** with:
# >    - Name
# >    - Score
# >    - Department
# 2. Convert it to a `pandas` DataFrame.
# 3. Write a function that classifies each student as `"PASS"` or `"FAIL"` and applies it to create a new `"Status"` column.
# 4. Use `groupby` (if you know it) or simple filtering to find:
# >    - The average score overall.
# >    - The average score per department.
# 5. Write a short paragraph summarising your findings (e.g. which department performed best).

# %% [markdown]
# ## 11. Summary and Reflection (Week 10 PH)

# %% [markdown]
# In this Week 10 practical, you have:
#
# - Written and run basic **Python code** in a notebook.
# - Used **variables**, **basic data types**, **lists**, **dictionaries**, **if-statements**, **loops**, and **functions**.
# - Created a simple `pandas` **DataFrame** and performed basic selection and filtering.
# - Connected core programming concepts to **data science workflows**.
#
# > 🧠 **Final Reflection (1–2 paragraphs):**
# > - Which Python concept (variables, lists, dictionaries, loops, functions, pandas) felt easiest to you? Which was most challenging?
# > - How do you see these programming skills helping you in later courses like machine learning, AI, or software development?
# > - What would you like to be able to program by the end of your degree?
